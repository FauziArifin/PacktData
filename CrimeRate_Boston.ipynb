# %% [markdown]
# <a href="https://colab.research.google.com/github/FauziArifin/PacktData/blob/master/CrimeRate_Boston.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import statsmodels.graphics.api as smg
import pandas as pd
import numpy as np
import patsy
from statsmodels.graphics.correlation import plot_corr
from sklearn.model_selection import train_test_split
plt.style.use('seaborn')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
rawBostonData = 'https://raw.githubusercontent.com/PacktWorkshops/The-Data-Science-Workshop/master/Chapter02/Dataset/Boston.csv'
df_boston = pd.read_csv(rawBostonData)

# %%
df_boston.head()
# Out:
#       CRIM   ZN   INDUS   CHAS    NOX  ...  RAD  TAX  PTRATIO  LSTAT  MEDV
# 0  0.00632  18.0    2.31     0  0.538  ...    1  296     15.3   4.98  24.0
# 1  0.02731   0.0    7.07     0  0.469  ...    2  242     17.8   9.14  21.6
# 2  0.02729   0.0    7.07     0  0.469  ...    2  242     17.8   4.03  34.7
# 3  0.03237   0.0    2.18     0  0.458  ...    3  222     18.7   2.94  33.4
# 4  0.06905   0.0    2.18     0  0.458  ...    3  222     18.7   5.33  36.2
#
# [5 rows x 13 columns]

# %%
df_boston.isnull().sum()
# Out:
# CRIM       0
#  ZN        0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
df_boston.drop_duplicates()
# Out:
#         CRIM   ZN   INDUS   CHAS    NOX  ...  RAD  TAX  PTRATIO  LSTAT  MEDV
# 0    0.00632  18.0    2.31     0  0.538  ...    1  296     15.3   4.98  24.0
# 1    0.02731   0.0    7.07     0  0.469  ...    2  242     17.8   9.14  21.6
# 2    0.02729   0.0    7.07     0  0.469  ...    2  242     17.8   4.03  34.7
# 3    0.03237   0.0    2.18     0  0.458  ...    3  222     18.7   2.94  33.4
# 4    0.06905   0.0    2.18     0  0.458  ...    3  222     18.7   5.33  36.2
# ..       ...   ...     ...   ...    ...  ...  ...  ...      ...    ...   ...
# 501  0.06263   0.0   11.93     0  0.573  ...    1  273     21.0   9.67  22.4
# 502  0.04527   0.0   11.93     0  0.573  ...    1  273     21.0   9.08  20.6
# 503  0.06076   0.0   11.93     0  0.573  ...    1  273     21.0   5.64  23.9
# 504  0.10959   0.0   11.93     0  0.573  ...    1  273     21.0   6.48  22.0
# 505  0.04741   0.0   11.93     0  0.573  ...    1  273     21.0   7.88  11.9
#
# [506 rows x 13 columns]

# %%
list(df_boston.columns)
# Out:
# ['CRIM',
#  ' ZN ',
#  'INDUS ',
#  'CHAS',
#  'NOX',
#  'RM',
#  'AGE',
#  'DIS',
#  'RAD',
#  'TAX',
#  'PTRATIO',
#  'LSTAT',
#  'MEDV']

# %%
df_renamed_boston = df_boston.rename(columns = {
    'CRIM' : 'crimeRatePerCapita',
 ' ZN ' : 'landOver25K_sqft',
 'INDUS ' : 'non-retailLandProptn',
 'CHAS' : 'riverDummy',
 'NOX' : 'nitrixOxidine_pp10m',
 'RM' : 'AvgNo.RoomsPerDwelling',
 'AGE' : 'ProptnOwnerOccupied',
 'DIS' : 'weightedDist',
 'RAD' : 'radialHighwaysAccess',
 'TAX' : 'propTaxRate_per10K',
 'PTRATIO' : 'pupilTeacherRatio',
 'LSTAT' : 'pctLowerStatus',
 'MEDV' : 'medianValue_Ks'
})

# %%
df_renamed_boston.head()
# Out:
#    crimeRatePerCapita  landOver25K_sqft  ...  pctLowerStatus  medianValue_Ks
# 0             0.00632              18.0  ...            4.98            24.0
# 1             0.02731               0.0  ...            9.14            21.6
# 2             0.02729               0.0  ...            4.03            34.7
# 3             0.03237               0.0  ...            2.94            33.4
# 4             0.06905               0.0  ...            5.33            36.2
#
# [5 rows x 13 columns]

# %%
df_renamed_boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   crimeRatePerCapita      506 non-null    float64
#  1   landOver25K_sqft        506 non-null    float64
#  2   non-retailLandProptn    506 non-null    float64
#  3   riverDummy              506 non-null    int64
#  4   nitrixOxidine_pp10m     506 non-null    float64
#  5   AvgNo.RoomsPerDwelling  506 non-null    float64
#  6   ProptnOwnerOccupied     506 non-null    float64
#  7   weightedDist            506 non-null    float64
#  8   radialHighwaysAccess    506 non-null    int64
#  9   propTaxRate_per10K      506 non-null    int64
#  10  pupilTeacherRatio       506 non-null    float64
#  11  pctLowerStatus          506 non-null    float64
#  12  medianValue_Ks          506 non-null    float64
# dtypes: float64(10), int64(3)
# memory usage: 51.5 KB

# %%
df_renamed_boston.describe(include=[np.number]).T
# Out:
#                         count        mean  ...         75%       max
# crimeRatePerCapita      506.0    3.613524  ...    3.677082   88.9762
# landOver25K_sqft        506.0   11.363636  ...   12.500000  100.0000
# non-retailLandProptn    506.0   11.136779  ...   18.100000   27.7400
# riverDummy              506.0    0.069170  ...    0.000000    1.0000
# nitrixOxidine_pp10m     506.0    0.554695  ...    0.624000    0.8710
# AvgNo.RoomsPerDwelling  506.0    6.284634  ...    6.623500    8.7800
# ProptnOwnerOccupied     506.0   68.574901  ...   94.075000  100.0000
# weightedDist            506.0    3.795043  ...    5.188425   12.1265
# radialHighwaysAccess    506.0    9.549407  ...   24.000000   24.0000
# propTaxRate_per10K      506.0  408.237154  ...  666.000000  711.0000
# pupilTeacherRatio       506.0   18.455534  ...   20.200000   22.0000
# pctLowerStatus          506.0   12.653063  ...   16.955000   37.9700
# medianValue_Ks          506.0   22.532806  ...   25.000000   50.0000
#
# ...

# %%
X = df_renamed_boston.drop('crimeRatePerCapita', axis = 1)
Y = df_renamed_boston['crimeRatePerCapita']
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3, random_state = 10)
train = pd.concat([x_train, y_train], axis = 1)
test = pd.concat([x_test, y_test],axis = 1)

# %%
# corrMatrix = train.corr(method = 'pearson')
# plot_corr(corrMatrix, xnames = list(train.columns), ynames = list(train.columns), title = None, normcolor = False, cmap = 'RdYlBu_r')

# %%
fig, ax = plt.subplots(figsize=(10,10))         # Sample figsize in inches
sns.heatmap(train.corr(), annot = True, fmt='.1g', ax=ax)
